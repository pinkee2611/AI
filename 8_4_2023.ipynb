# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkee2611/AI/blob/main/8_4_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar100
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train.shape
y_train.shape
# Out:
# (50000, 1)

# %%
class_name=['beaver', 'dolphin', 'otter', 'seal', 'whale','aquarium fish', 'flatfish', 'ray', 'shark',
'trout','orchids', 'poppies', 'roses', 'sunflowers', 'tulips','bottles', 'bowls', 'cans', 'cups',
'plates','apples', 'mushrooms', 'oranges', 'pears', 'sweet peppers','clock', 'computer keyboard', 'lamp', 'telephone', 'television','bed', 'chair', 'couch', 'table', 'wardrobe',
'bee', 'beetle', 'butterfly', 'caterpillar', 'cockroach','bear', 'leopard', 'lion', 'tiger', 'wolf','bridge', 'castle', 'house',
'road', 'skyscraper','cloud', 'forest', 'mountain', 'plain', 'sea','camel', 'cattle', 'chimpanzee', 'elephant', 'kangaroo',
'camel', 'cattle', 'chimpanzee', 'elephant', 'kangaroo','fox', 'porcupine', 'possum', 'raccoon', 'skunk','crab', 'lobster', 'snail', 'spider', 'worm','baby', 'boy', 'girl', 'man', 'woman',
'crocodile', 'dinosaur', 'lizard', 'snake', 'turtle','hamster', 'mouse', 'rabbit', 'shrew', 'squirrel','maple', 'oak', 'palm', 'pine', 'willow','bicycle', 'bus', 'motorcycle', 'pickup truck', 'train',
'lawn-mower', 'rocket', 'streetcar', 'tank', 'tractor']

# %%
import matplotlib as plt
for i in range (30):
  plt.subplot(5,6,i+1)
  plt.imshow(x_train[500+i])
  plt.title(class_name[y_train[500+i]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9a4705440be0> in <cell line: 2>()
#       1 import matplotlib as plt
#       2 for i in range (30):
# ----> 3   plt.subplot(5,6,i+1)
#       4   plt.imshow(x_train[500+i])
#       5   plt.title(class_name[y_train[500+i]])
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     224         if name in props:
#     225             return props[name].__get__(instance)
# --> 226         raise AttributeError(
#     227             f"module {cls.__module__!r} has no attribute {name!r}")
#     228
#
# AttributeError: module 'matplotlib' has no attribute 'subplot'

# %%
x_train,x_test=x_train/255.0,x_test/255.0

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical
x_train=x_train,reshape(500,32*32*3)
model = Sequential()
model.add(Dense(500,activation='relu',input_shape=(32*32*3)))
model.add(Dense(500,activation='relu'))
model.add(Dense(300,activation='relu'))
model.add(Dense(100,activation='softmax'))
model.summary()
y_train = to_categorical(y_train,100)
y_test = to_categorical(y_test,100)
model.compile(loss='sparse_categorical_crossemtropy',optimizer='sgd',metrics=['accumary'])
history=model.fit(x_train,y_train,eepoch=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7546be2376ac> in <cell line: 4>()
#       2 from keras.layers import Dense, Flatten
#       3 from keras.utils import to_categorical
# ----> 4 x_train=x_train,reshape(500,32*32*3)
#       5 model = Sequential()
#       6 model.add(Dense(500,activation='relu',input_shape=(32*32*3)))
#
# NameError: name 'x_train' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
folder = '/content/drive/MyDrive/60_anh/'
for i in range(60):
  plt.subplot(10,6,i+1)
  filename=folder+'phuc ('+str((i+1))+').jpg'
  img=imread(filename)
  plt.imshow(img)
plt.imshow(img)

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.utils import load_img,img_to_array
folder = '/content/drive/MyDrive/60_anh/'
photos,labels=list(),list()
for file in listdir(folder):
  output= 0.0
  if file.startswith('phuc'):
    output=1
  if file.startswith('danh'):
    output=2
  img=load_img(folder+file)
  photo=img_to_array(img)
  photos.append(photo)
  labels.append(output)
photos=asarray(photo)
labels=asarray(labels)
print(photo.shape,labels.shape)
save('phuc_danh_photos.npy',photos)
save('phuc_danh_photos.npy',labels)
# Out:
# (30, 40, 3) (120,)

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/file AI/pima-indians-diabetes.csv')
data.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
x.shape
# Out:
# (767, 8)

# %%
y.shape
# Out:
# (767,)

# %%
x=data.iloc[:,0:8]
y=data.iloc[:,8]
import seaborn as sns
sns.pairplot(x)

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
x = SS.fit_transform(x)
model = Sequential()
model.add(Dense(12,activation = 'relu', input_shape = (8,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model.fit(x,y,epochs = 1000,batch_size = 10)
_,accuracy = model.evaluate(x,y)
print('Độ chính xác của mô hình là: %2f'%(accuracy*100))
# Out:
# Epoch 1/1000
# 77/77 [==============================] - 1s 2ms/step - loss: 0.6661 - accuracy: 0.6480
# Epoch 2/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6196 - accuracy: 0.6519
# Epoch 3/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5794 - accuracy: 0.6545
# Epoch 4/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.6741
# Epoch 5/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.7327
# Epoch 6/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.7640
# Epoch 7/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4901 - accuracy: 0.7784
# Epoch 8/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 0.7875
# Epoch 9/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4711 - accuracy: 0.7823
# Epoch 10/1000
# ...
