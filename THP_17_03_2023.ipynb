# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkee2611/AI/blob/main/THP_17_03_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import numpy as np

url = 'mtcars.csv'
data= pd.read_csv(url)
data.head()

data.hist()
plt.show

correlation = data.corr()
print(correlation)

sns.heatmap (correlation,annot=True)

sns.pairplot(data)

model= linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print('he so intercept la:',model.intercept_)
print('he so coeffient la:', model.coef_)

model.score(X=pd.DataFrame(data['wt']),y=data['mpg'])

y_pred = model.predict(X=pd.DataFrame(data['wt']))
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black', xlim=(0,7))
plt.plot(data['wt'],y_pred,color='blue')

X=pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh:',model.intercept_)
print('coeffinet cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['mpg']))

range = np.arange (1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range, y_pred, color='blue')

model= linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5,
                data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh:',model.intercept_)
print('coeffinet cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['mpg']))

range = np.arange (1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,
                        range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range, y_pred, color='blue')

model= linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp','disp']],y=data['mpg'])
print('intercept là:',model.intercept_)
print('coefficient là:',model.coef_)
print('độ chính xác: ',model.score(X=data.loc[:,['wt','hp','disp']],y=data['mpg']))
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# he so intercept la: 37.28512616734204
# he so coeffient la: [-5.34447157]
# intercept cua mo hinh: 49.93081094945181
# coeffinet cua mo hinh: [-13.38033708   1.17108689]
# Do chinh xac cua mo hinh: 0.8190613581384094
# intercept cua mo hinh: -14921.11995188375
# coeffinet cua mo hinh: [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Do chinh xac cua mo hinh: 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import numpy as np

url='50_Startups.csv'
data1= pd.read_csv(url)
data1.head()
data1.hist()

correlation = data1.corr()

sns.heatmap (correlation,annot=True)
sns.pairplot(data1)

model1= linear_model.LinearRegression()
model1.fit(X=pd.DataFrame(data1['Administration']),y=data1['Profit'])

model1.score(X=pd.DataFrame(data1['Administration']),y=data1['Profit'])
y_pred = model1.predict(X=pd.DataFrame(data1['Administration']))
data1.plot(kind='scatter',x='Administration',y='Profit',figsize=(9,9),color='black')
plt.plot(data1['Administration'],y_pred,color='blue')

X=pd.DataFrame([data1['Administration'],data1['Administration']**2]).T
model.fit(X,y=data1['Profit'])
print('intercept cua mo hinh:',model.intercept_)
print('coeffinet cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['Profit']))

X=pd.DataFrame([data1['Administration']]).T
model.fit(X,y=data1['Profit'])
print('intercept cua mo hinh:',model.intercept_)
print('coeffinet cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:', model.score(X,y=data['Profit']))

model= linear_model.LinearRegression()
model.fit(X=data.loc[:,['Administration']],y=data['Profit'])
print('intercept là:',model.intercept_)
print('coefficient là:',model.coef_)
print('độ chính xác: ',model.score(X=data.loc[:,['Administration']],y=data['Profit']))

model11= linear_model.LinearRegression()
X=pd.DataFrame([data1['Administration'],data1['Administration']**2,data1['Administration']**3,data1['Administration']**4,data1['Administration']**5,
                data1['Administration']**6,data1['Administration']**7,data1['Administration']**8,data1['Administration']**9,data1['Administration']**10]).T
model11.fit(X,y=data1['Administration'])
print('intercept cua mo hinh:',model11.intercept_)
print('coeffinet cua mo hinh:',model11.coef_)
print('Do chinh xac cua mo hinh:', model11.score(X,y=data1['Administration']))

range = np.arange (50000,185000,100)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,
                        range**6,range**7,range**8,range**9,range**10]).T
y_predict = model11.predict(X=X_range)
data.plot(kind='scatter',x='Administration',y='Profit',figsize=(9,9),color='black')
plt.plot(range, y_predict, color='blue')
# Out:
# intercept cua mo hinh: -4368.18544101929
# coeffinet cua mo hinh: [ 1.79945854e+00 -6.58158097e-06]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
url= 'insurance.csv'
data=pd.read_csv(url)

data.sample(5)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
print(data['sex'].value_counts())
sns.countplot(x='sex',data=data)
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# <Axes: xlabel='sex', ylabel='count'>

# %%
print(data['smoker'].value_counts())
sns.countplot(x='smoker',data=data)
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64
# <Axes: xlabel='smoker', ylabel='count'>

# %%
print(data['region'].value_counts())
sns.countplot(x='region',data=data)
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64
# <Axes: xlabel='region', ylabel='count'>

# %%
corr= data.corr()
sns.heatmap(corr,cmap='Wistia',annot=True)
# Out:
# <Axes: >
